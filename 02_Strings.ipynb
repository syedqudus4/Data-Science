# %% [markdown]
# <a href="https://colab.research.google.com/github/syedqudus4/Data-Science/blob/main/02_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strings

# %%
s = "This is a string"
print(s)
# Out:
# This is a string

# %%
s = 'This is also a srtign'
print(s)
# Out:
# This is also a srtign

# %%
s = 'He said, "I would like to visit you"'
print(s)
# Out:
# He said, "I would like to visit you"

# %%
s = "He said, he's fine"
print(s)
# Out:
# He said, he's fine

# %%
x = 4
y = 3

print(f"x + y is {x+y}")
# Out:
# x + y is 7

# %%
#'a', 'c' ,'d', 'acd'

s = "acdaedgsfr"
print(s[::-1])
# Out:
# rfsgdeadca

# %%
print(len(s))
# Out:
# 10

# %%
print(s)
# Out:
# acdaedgsfr

# %%
#funcaiton attached to an object are called methods

# %%
print(s.capitalize())
name = "Naeem Khan"

names = name.split(" ")
# Out:
# Acdaedgsfr

# %%
def s_endswith(s, c):
  if s[-1] == c:
    return True

  else:
    return False

# %%
test = "this."
print(test.endswith("k"))
print(s_endswith(test, "."))
# Out:
# False
# True

# %%
dir(s)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
title = input("Please enter your title: ")
name = input("Pleaes enter your name: ")
age = input("Please enter your age: ")
occ = input("Please enter your occ: ")

print(title + " " + name + " is " + age + " years old and works as a " + occ )
print(f"{title} {name} is {age} years old and works as a {occ}")
# Out:
# Please enter your title: dr
# Pleaes enter your name: lkhan
# Please enter your age: 35
# Please enter your occ: teacher
# dr lkhan is 35 years old and works as a teacher
# dr lkhan is 35 years old and works as a teacher

# %%
s = "my name is \t naeem \n. I will write backslash \\"
print(s)
# Out:
# my name is 	 naeem
# . I will write backslash \

# %%
fname = "Ali"

# %%
x = input("Enter a name")
# Out:
# Enter a nameNaeem

# %%
s = "This is a string"
print(s[::-1])
# Out:
# gnirts a si sihT

# %%
x = "7"
y = "8"

print(x*3)
# Out:
# 777

# %%
x = "this is \t a \n \\ overwriting"
print(x)
# Out:
# this is 	 a
#  \ overwriting

# %%
age = input("Enter your age")
name = input("Enter you name")
print(f" {name} is {age} years old")
# Out:
# Enter your age30
# Enter you namekhane
#  khane is 30 years old

# %% [markdown]
# Strings are used in Python to record text information, such as names. Strings in Python are actually a *sequence*, which basically means Python keeps track of every element in the string as a sequence. For example, Python understands the string "hello' to be a sequence of letters in a specific order. This means we will be able to use indexing to grab particular letters (like the first letter, or the last letter).
#
# This idea of a sequence is an important one in Python and we will touch upon it later on in the future.
#
# In this lecture we'll learn about the following:
#
#     1.) Creating Strings
#     2.) Printing Strings
#     3.) String Indexing and Slicing
#     4.) String Properties
#     5.) String Methods
#     6.) Print Formatting

# %%
my_str = "This is \"the\" string"
print(my_str)
# Out:
# This is "the" string

# %%
my_str = "first"
my_str = "second"
#my_str[0] = "c"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-47bb0eeb96f5> in <module>
#       1 my_str = "first"
#       2 my_str = "second"
# ----> 3 my_str[0] = "c"
#
# TypeError: 'str' object does not support item assignment

# %%
my_str="naeem_khan_1234"
fname, sname, number = my_str.split("_")
print(fname)
print(sname)
print(number)
# Out:
# naeem
# khan
# 1234

# %%
my_list = ["Apple" , "a" , "day", "keeps","doctors","away"]
my_str = " ".join(my_list)
print(my_str)
# Out:
# Apple a day keeps doctors away

# %%
name = "Ibrahim"
age = "abc"
print(f"{name} is {age} years old")
# Out:
# Ibrahim is abc years old

# %%
my_str = "This is test"
print(my_str[::-1])
# Out:
# tset si sihT

# %%
my_str = 'He said, "Thank you"'
str2 = "You are the best!"

#print(my_str + " " + str2)
print(f"{my_str} tahti is thteh sts the {str2}")
# Out:
# He said,	 "Thank you" tahti is thteh sts the You are the best!

# %%
name = 'naeem khan'
parts = name.title().split(" ")
print(parts)
# Out:
# ['Naeem', 'Khan']

# %%
my_str1 = "naeem"
my_str2 = "khan"

print(my_str1 *3)
# Out:
# naeemnaeemnaeem

# %% [markdown]
# ## Creating a String
# To create a string in Python you need to use either single quotes or double quotes. For example:

# %%
# he said, "wow"
s = "he said this in the last meeting"

l = s.split(" ")
l2 = l[::-1]
s2 = " ".join(l2)
print(s2)
# Out:
# meeting last the in this said he

# %%
# Single word
x="hello, I love Python Programming"
y='c'
print(type(y))

#he said, "I am a good boy",

x= "he said, 'I am a good boy',"
print(x)
# Out:
# <class 'str'>
# he said, 'I am a good boy',

# %%
# Entire phrase
'This is also a string'
# Out:
# 'This is also a string'

# %%
# We can also use double quote
"String built with double quotes"
# Out:
# 'String built with double quotes'

# %%
# Be careful with quotes!
' I'm using single quotes, but this will create an error'
# Out:
#   File "<ipython-input-4-da9a34b3dc31>", line 2
#     ' I'm using single quotes, but this will create an error'
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# The reason for the error above is because the single quote in <code>I'm</code> stopped the string. You can use combinations of double and single quotes to get the complete statement.

# %%
"Now I'm ready to use the single quotes inside a string!"
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %% [markdown]
# Now let's learn about printing strings!

# %% [markdown]
# ## Printing a String
#
# Using Jupyter notebook with just a string in a cell will automatically output strings, but the correct way to display strings in your output is by using a print function.

# %%
# We can simply declare a string
'Hello World'
# Out:
# 'Hello World'

# %%
# Note that we can't output multiple strings this way
'Hello World 1'
'Hello World 2'
# Out:
# 'Hello World 2'

# %%
x="student 1 \t \t"
y="student 2"
print(x, y)
# Out:
# student 1 	 	 student 2

# %% [markdown]
# We can use a print statement to print a string.

# %%
print('Hello World 1')
print('Hello World 2')
print('Use \n to print a new line')
print('\n')
print('See what I mean?')
# Out:
# Hello World 1
# Hello World 2
# Use
#  to print a new line
#
#
# See what I mean?

# %%
len("Hello This is me")
# Out:
# 16

# %%
x="This is the"

if (len(x)>15):
  print("you are over the limit of 15 characters")

else:
  print("you are fine")
# Out:
# you are fine

# %% [markdown]
# ## String Basics

# %% [markdown]
# We can also use a function called len() to check the length of a string!

# %%
len('Hello World')
# Out:
# 11

# %% [markdown]
# Python's built-in len() function counts all of the characters in the string, including spaces and punctuation.

# %% [markdown]
# ## String Indexing
# We know strings are a sequence, which means Python can use indexes to call parts of the sequence. Let's learn how this works.
#
# In Python, we use brackets <code>[]</code> after an object to call its index. We should also note that indexing starts at 0 for Python. Let's create a new object called <code>s</code> and then walk through a few examples of indexing.

# %%
# Assign s as a string
s = 'Hello World'

# %%
#Check
s
# Out:
# 'Hello World'

# %%
# Print the object
print(s)
# Out:
# Hello World

# %% [markdown]
# Let's start indexing!

# %%
# Show first element (in this case a letter)
s[0]
# Out:
# 'H'

# %%
s[1]
# Out:
# 'e'

# %%
s[2]
# Out:
# 'l'

# %% [markdown]
# We can use a <code>:</code> to perform *slicing* which grabs everything up to a designated point. For example:

# %%
# Grab everything past the first term all the way to the length of s which is len(s)
s[1:]
# Out:
# 'ello World'

# %%
# Note that there is no change to the original s
s
# Out:
# 'Hello World'

# %%
# Grab everything UP TO the 3rd index
s[:3]
# Out:
# 'Hel'

# %% [markdown]
# Note the above slicing. Here we're telling Python to grab everything from 0 up to 3. It doesn't include the 3rd index. You'll notice this a lot in Python, where statements and are usually in the context of "up to, but not including".

# %%
#Everything
s[:]
# Out:
# 'Hello World'

# %% [markdown]
# We can also use negative indexing to go backwards.

# %%
# Last letter (one index behind 0 so it loops back around)
s[-1]
# Out:
# 'd'

# %%
# Grab everything but the last letter
s[:-1]
# Out:
# 'Hello Worl'

# %% [markdown]
# We can also use index and slice notation to grab elements of a sequence by a specified step size (the default is 1). For instance we can use two colons in a row and then a number specifying the frequency to grab elements. For example:

# %%
# Grab everything, but go in steps size of 1
s[::1]
# Out:
# 'Hello World'

# %%
# Grab everything, but go in step sizes of 2
s[::2]
# Out:
# 'HloWrd'

# %%
# We can use this to print a string backwards
s[::-1]
# Out:
# 'dlroW olleH'

# %% [markdown]
# ## String Properties
# It's important to note that strings have an important property known as *immutability*. This means that once a string is created, the elements within it can not be changed or replaced. For example:

# %%
s
# Out:
# 'Hello World'

# %%
# Let's try to change the first letter to 'x'
s[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-976942677f11> in <module>()
#       1 # Let's try to change the first letter to 'x'
# ----> 2 s[0] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Notice how the error tells us directly what we can't do, change the item assignment!
#
# Something we *can* do is concatenate strings!

# %%
s
# Out:
# 'Hello World'

# %%
# Concatenate strings!
s + ' concatenate me!'
# Out:
# 'Hello World concatenate me!'

# %%
# We can reassign s completely though!
s = s + ' concatenate me!'

# %%
print(s)
# Out:
# Hello World concatenate me!

# %%
s
# Out:
# 'Hello World concatenate me!'

# %% [markdown]
# We can use the multiplication symbol to create repetition!

# %%
letter = 'z'

# %%
letter*10
# Out:
# 'zzzzzzzzzz'

# %% [markdown]
# ## Basic Built-in String methods
#
# Objects in Python usually have built-in methods. These methods are functions inside the object (we will learn about these in much more depth later) that can perform actions or commands on the object itself.
#
# We call methods with a period and then the method name. Methods are in the form:
#
# object.method(parameters)
#
# Where parameters are extra arguments we can pass into the method. Don't worry if the details don't make 100% sense right now. Later on we will be creating our own objects and functions!
#
# Here are some examples of built-in methods in strings:

# %%
s
# Out:
# 'Hello World concatenate me!'

# %%
# Upper Case a string
s.upper()
# Out:
# 'HELLO WORLD CONCATENATE ME!'

# %%
# Lower case
s.lower()
# Out:
# 'hello world concatenate me!'

# %%
# Split a string by blank space (this is the default)
s.split()
# Out:
# ['Hello', 'World', 'concatenate', 'me!']

# %%
# Split by a specific element (doesn't include the element that was split on)
s.split('W')
# Out:
# ['Hello ', 'orld concatenate me!']

# %% [markdown]
# There are many more methods than the ones covered here. Visit the Advanced String section to find out more!

# %% [markdown]
# ## Print Formatting
#
# We can use the .format() method to add formatted objects to printed string statements.
#
# The easiest way to show this is through an example:

# %%
'Insert another string with curly brackets: {}'.format('The inserted string')
# Out:
# 'Insert another string with curly brackets: The inserted string'

# %% [markdown]
# ## Python has great support for strings:

# %%
hello = 'hello'    # String literals can use single quotes
world = "world"    # or double quotes; it does not matter.
print(hello)       # Prints "hello"
print(len(hello))  # String length; prints "5"
hw = hello + ' ' + world  # String concatenation
print(hw)  # prints "hello world"
hw12 = '%s %s %d' % (hello, world, 12)  # sprintf style string formatting
print(hw12)  # prints "hello world 12"
hw21 = '{} {} {}'.format(hello, world, 21)  # formatting with format function
print(hw21)  # prints "hello world 21"
hw13 = '{} {} {:.2f}'.format(hello, world, 1 / 3)  # float formatting
print(hw13)  # prints "hello world 0.33"
hw3 = f'{hello} {world} {1 / 3:.2f}' # the new f-strings
print(hw3)  # prints "hello world 0.33"
# Out:
# hello
# 5
# hello world
# hello world 12
# hello world 21
# hello world 0.33
# hello world 0.33

# %%
my_str1 = 'Naeemullah'
my_str2 = 'Khan'
'{} {} woohoo {:.6f}'.format(my_str1, my_str2, 1/3)
# Out:
# 'Naeemullah Khan woohoo 0.333333'

# %%
print('The {0} is {1} and {2}!'.format('fox', 'brown', 'quick'))
# Out:
# The fox is brown and quick!

# %%
print('The {p} is {q} and {v}!'.format(p='fox', q='brown' , v='quick'))
# Out:
# The fox is brown and quick!

# %%
x="0123456789"

print(x[1:8:2])
# Out:
# 1357

# %%
x="This is my first string"
y="string2"


z=x.split(' ')
print(z[2])
# Out:
# my
